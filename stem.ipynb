# %%
from thefuzz import fuzz
from thefuzz import process

# %%
fuzz.ratio("data analysis", "data analyst")
# Out:
# 88

# %%
l=['Data Analysis', 'SQL Server', 'Data Analytics', 'powerbi', 'SQL', 'MSBI', 'Oracle', 'Training', 'tableau', 'Time management', 'Analytical', 'Data collection', 'Data analytics', 'Data Analyst', 'data visualization', 'SQL', 'Data analysis', 'Environmental science', 'Business analytics', 'Diversity and Inclusion', 'Finance', 'Corporate', 'ISS', 'Data Analyst', 'Data analytics', 'Data mining', 'Excel', 'Pivot Table', 'VLOOKUP', 'Formulas', 'Advanced Excel', 'HLOOKUP', 'BPO', 'Report Automation', 'SQL Database', 'Data Analytics', 'Data Reporting', 'excel', 'Excel', 'data visualization', 'Tableau', 'SQL', 'Python', 'Data Analytics', 'SQL', 'Excel', 'Data Analytics', 'Python', 'Data analyst', 'Engineering', 'Power Plant', 'Administration', 'Automation', 'Electronics', 'Educational', 'Engineering Maintenance', 'Quarry', 'Electrical', 'Hospital', 'mis reporting', 'Data Management', 'HLOOKUP', 'VLOOKUP', 'Data Analysis', 'report generation', 'Data Extraction', 'Advanced Excel', 'sales', 'Pivot Table', 'data monitoring', 'Data Analytics', 'Data Reporting', 'Advanced Excel', 'Pivot Table', 'MS Excel', 'VLOOKUP', 'Formulas', 'HLOOKUP', 'Informatica', 'Data Quality', 'Data Management', 'Data Mining', 'Data Analyst', 'Data Modeling', 'Solution Design', 'ETL', 'Talend', 'Data Analytics', 'SQL', 'SQL', 'Business Intelligence', 'SAS', 'Data Visualization', 'Tableau', 'Data Analytics', 'Statistics', 'Analytics', 'Python', 'Diversity and Inclusion', 'Focus', 'Banking', 'SCALA', 'Agile', 'Data Analyst', 'Asset management', 'Financial services', 'Core banking', 'Python', 'excel', 'Financial Reporting', 'advance excel', 'Finance', 'Data Analysis', 'data analyst', 'data analytics', 'performing analysis', 'report preparation', 'data governance', 'mysql', 'Performance tuning', 'Coding', 'Artificial Intelligence', 'Machine learning', 'Data Analyst', 'Data analytics', 'Analyst 3', 'Statistics', 'Analytics', 'Data extraction', 'Performance tuning', 'Data analysis', 'SAP', 'spark', 'Data structures', 'big data', 'Monitoring', 'SQL', 'Data architecture', 'Python', 'Data Quality', 'data analysis', 'Data Management', 'Data Modeling', 'Data Governance']

# %% [markdown]
# Lowercase the elements of the list and print the result.

# %%
p=list(map(str.lower,l))
p
# Out:
# ['data analysis',
#  'sql server',
#  'data analytics',
#  'powerbi',
#  'sql',
#  'msbi',
#  'oracle',
#  'training',
#  'tableau',
#  'time management',
#  'analytical',
#  'data collection',
#  'data analytics',
#  'data analyst',
#  'data visualization',
#  'sql',
#  'data analysis',
#  'environmental science',
#  'business analytics',
#  'diversity and inclusion',
#  'finance',
#  'corporate',
#  'iss',
#  'data analyst',
#  'data analytics',
#  'data mining',
#  'excel',
#  'pivot table',
#  'vlookup',
#  'formulas',
#  'advanced excel',
#  'hlookup',
#  'bpo',
#  'report automation',
#  'sql database',
#  'data analytics',
#  'data reporting',
#  'excel',
#  'excel',
#  'data visualization',
#  'tableau',
#  'sql',
#  'python',
#  'data analytics',
#  'sql',
#  'excel',
#  'data analytics',
#  'python',
#  'data analyst',
#  'engineering',
#  'power plant',
#  'administration',
#  'automation',
#  'electronics',
#  'educational',
#  'engineering maintenance',
#  'quarry',
#  'electrical',
#  'hospital',
#  'mis reporting',
#  'data management',
#  'hlookup',
#  'vlookup',
#  'data analysis',
#  'report generation',
#  'data extraction',
#  'advanced excel',
#  'sales',
#  'pivot table',
#  'data monitoring',
#  'data analytics',
#  'data reporting',
#  'advanced excel',
#  'pivot table',
#  'ms excel',
#  'vlookup',
#  'formulas',
#  'hlookup',
#  'informatica',
#  'data quality',
#  'data management',
#  'data mining',
#  'data analyst',
#  'data modeling',
#  'solution design',
#  'etl',
#  'talend',
#  'data analytics',
#  'sql',
#  'sql',
#  'business intelligence',
#  'sas',
#  'data visualization',
#  'tableau',
#  'data analytics',
#  'statistics',
#  'analytics',
#  'python',
#  'diversity and inclusion',
#  'focus',
#  'banking',
#  'scala',
#  'agile',
#  'data analyst',
#  'asset management',
#  'financial services',
#  'core banking',
#  'python',
#  'excel',
#  'financial reporting',
#  'advance excel',
#  'finance',
#  'data analysis',
#  'data analyst',
#  'data analytics',
#  'performing analysis',
#  'report preparation',
#  'data governance',
#  'mysql',
#  'performance tuning',
#  'coding',
#  'artificial intelligence',
#  'machine learning',
#  'data analyst',
#  'data analytics',
#  'analyst 3',
#  'statistics',
#  'analytics',
#  'data extraction',
#  'performance tuning',
#  'data analysis',
#  'sap',
#  'spark',
#  'data structures',
#  'big data',
#  'monitoring',
#  'sql',
#  'data architecture',
#  'python',
#  'data quality',
#  'data analysis',
#  'data management',
#  'data modeling',
#  'data governance']

# %%
# set(l)

# %%
p[1]
# Out:
# 'sql server'

# %%
p
# Out:
# ['data analysis',
#  'sql server',
#  'data analytics',
#  'powerbi',
#  'sql',
#  'msbi',
#  'oracle',
#  'training',
#  'tableau',
#  'time management',
#  'analytical',
#  'data collection',
#  'data analytics',
#  'data analyst',
#  'data visualization',
#  'sql',
#  'data analysis',
#  'environmental science',
#  'business analytics',
#  'diversity and inclusion',
#  'finance',
#  'corporate',
#  'iss',
#  'data analyst',
#  'data analytics',
#  'data mining',
#  'excel',
#  'pivot table',
#  'vlookup',
#  'formulas',
#  'advanced excel',
#  'hlookup',
#  'bpo',
#  'report automation',
#  'sql database',
#  'data analytics',
#  'data reporting',
#  'excel',
#  'excel',
#  'data visualization',
#  'tableau',
#  'sql',
#  'python',
#  'data analytics',
#  'sql',
#  'excel',
#  'data analytics',
#  'python',
#  'data analyst',
#  'engineering',
#  'power plant',
#  'administration',
#  'automation',
#  'electronics',
#  'educational',
#  'engineering maintenance',
#  'quarry',
#  'electrical',
#  'hospital',
#  'mis reporting',
#  'data management',
#  'hlookup',
#  'vlookup',
#  'data analysis',
#  'report generation',
#  'data extraction',
#  'advanced excel',
#  'sales',
#  'pivot table',
#  'data monitoring',
#  'data analytics',
#  'data reporting',
#  'advanced excel',
#  'pivot table',
#  'ms excel',
#  'vlookup',
#  'formulas',
#  'hlookup',
#  'informatica',
#  'data quality',
#  'data management',
#  'data mining',
#  'data analyst',
#  'data modeling',
#  'solution design',
#  'etl',
#  'talend',
#  'data analytics',
#  'sql',
#  'sql',
#  'business intelligence',
#  'sas',
#  'data visualization',
#  'tableau',
#  'data analytics',
#  'statistics',
#  'analytics',
#  'python',
#  'diversity and inclusion',
#  'focus',
#  'banking',
#  'scala',
#  'agile',
#  'data analyst',
#  'asset management',
#  'financial services',
#  'core banking',
#  'python',
#  'excel',
#  'financial reporting',
#  'advance excel',
#  'finance',
#  'data analysis',
#  'data analyst',
#  'data analytics',
#  'performing analysis',
#  'report preparation',
#  'data governance',
#  'mysql',
#  'performance tuning',
#  'coding',
#  'artificial intelligence',
#  'machine learning',
#  'data analyst',
#  'data analytics',
#  'analyst 3',
#  'statistics',
#  'analytics',
#  'data extraction',
#  'performance tuning',
#  'data analysis',
#  'sap',
#  'spark',
#  'data structures',
#  'big data',
#  'monitoring',
#  'sql',
#  'data architecture',
#  'python',
#  'data quality',
#  'data analysis',
#  'data management',
#  'data modeling',
#  'data governance']

# %%
i=0
n={}
for i in range(len(p)):
    for j in range(i+1,len(p)):
        # print(p[i],p[j])
        if fuzz.ratio(p[i],p[j])>80 and  p[j]!="-1" and p[i]!="-1":
            print(p[i],p[j])
            p[j]="-1"
            if p[i] in n:
                n[p[i]]+=1
            else:
                n[p[i]]=1
# Out:
# data analysis data analytics
# data analysis data analytics
# data analysis data analyst
# data analysis data analysis
# data analysis data analyst
# data analysis data analytics
# data analysis data analytics
# data analysis data analytics
# data analysis data analytics
# data analysis data analyst
# data analysis data analysis
# data analysis data analytics
# data analysis data analyst
# data analysis data analytics
# data analysis data analytics
# data analysis data analyst
# data analysis data analysis
# data analysis data analyst
# data analysis data analytics
# data analysis data analyst
# data analysis data analytics
# data analysis data analysis
# data analysis data analysis
# sql sql
# sql sql
# sql sql
# sql sql
# sql sql
# sql sql
# tableau tableau
# tableau tableau
# analytical analytics
# analytical analytics
# data visualization data visualization
# data visualization data visualization
# diversity and inclusion diversity and inclusion
# finance finance
# data mining data mining
# excel excel
# excel excel
# excel excel
# excel excel
# pivot table pivot table
# pivot table pivot table
# vlookup hlookup
# vlookup hlookup
# vlookup vlookup
# vlookup vlookup
# vlookup hlookup
# formulas formulas
# advanced excel advanced excel
# advanced excel advanced excel
# advanced excel advance excel
# data reporting data reporting
# python python
# python python
# python python
# python python
# data management data management
# data management asset management
# data management data management
# data extraction data extraction
# data quality data quality
# data modeling data modeling
# statistics statistics
# data governance data governance
# performance tuning performance tuning

# %%
print(n)
# Out:
# {'data analysis': 23, 'sql': 6, 'tableau': 2, 'analytical': 2, 'data visualization': 2, 'diversity and inclusion': 1, 'finance': 1, 'data mining': 1, 'excel': 4, 'pivot table': 2, 'vlookup': 5, 'formulas': 1, 'advanced excel': 3, 'data reporting': 1, 'python': 4, 'data management': 3, 'data extraction': 1, 'data quality': 1, 'data modeling': 1, 'statistics': 1, 'data governance': 1, 'performance tuning': 1}

# %%
{k: v for k, v in sorted(n.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'data analysis': 23,
#  'sql': 6,
#  'vlookup': 5,
#  'excel': 4,
#  'python': 4,
#  'advanced excel': 3,
#  'data management': 3,
#  'tableau': 2,
#  'analytical': 2,
#  'data visualization': 2,
#  'pivot table': 2,
#  'diversity and inclusion': 1,
#  'finance': 1,
#  'data mining': 1,
#  'formulas': 1,
#  'data reporting': 1,
#  'data extraction': 1,
#  'data quality': 1,
#  'data modeling': 1,
#  'statistics': 1,
#  'data governance': 1,
#  'performance tuning': 1}

# %%
fuzz.ratio("data analysis", "data analytics")
# Out:
# 81

# %%
m={}
for i in p:
    if i in m:
        m[i]+=1
    else:
        m[i]=1

{k: v for k, v in sorted(m.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'data analytics': 11,
#  'sql': 7,
#  'data analyst': 7,
#  'data analysis': 6,
#  'excel': 5,
#  'python': 5,
#  'tableau': 3,
#  'data visualization': 3,
#  'pivot table': 3,
#  'vlookup': 3,
#  'advanced excel': 3,
#  'hlookup': 3,
#  'data management': 3,
#  'diversity and inclusion': 2,
#  'finance': 2,
#  'data mining': 2,
#  'formulas': 2,
#  'data reporting': 2,
#  'data extraction': 2,
#  'data quality': 2,
#  'data modeling': 2,
#  'statistics': 2,
#  'analytics': 2,
#  'data governance': 2,
#  'performance tuning': 2,
#  'sql server': 1,
#  'powerbi': 1,
#  'msbi': 1,
#  'oracle': 1,
#  'training': 1,
#  'time management': 1,
#  'analytical': 1,
#  'data collection': 1,
#  'environmental science': 1,
#  'business analytics': 1,
#  'corporate': 1,
#  'iss': 1,
#  'bpo': 1,
#  'report automation': 1,
#  'sql database': 1,
#  'engineering': 1,
#  'power plant': 1,
#  'administration': 1,
#  'automation': 1,
#  'electronics': 1,
#  'educational': 1,
#  'engineering maintenance': 1,
#  'quarry': 1,
#  'electrical': 1,
#  'hospital': 1,
#  'mis reporting': 1,
#  'report generation': 1,
#  'sales': 1,
#  'data monitoring': 1,
#  'ms excel': 1,
#  'informatica': 1,
#  'solution design': 1,
#  'etl': 1,
#  'talend': 1,
#  'business intelligence': 1,
#  'sas': 1,
#  'focus': 1,
#  'banking': 1,
#  'scala': 1,
#  'agile': 1,
#  'asset management': 1,
#  'financial services': 1,
#  'core banking': 1,
#  'financial reporting': 1,
#  'advance excel': 1,
#  'performing analysis': 1,
#  'report preparation': 1,
#  'mysql': 1,
#  'coding': 1,
#  'artificial intelligence': 1,
#  'machine learning': 1,
#  'analyst 3': 1,
#  'sap': 1,
#  'spark': 1,
#  'data structures': 1,
#  'big data': 1,
#  'monitoring': 1,
#  'data architecture': 1}

# %%
for i in m:
    for j in m:
        if i!=j:
            if fuzz.ratio(i,j)>80:
                print(i,m[i],j,m[j])
                m[i]+=m[j]
                print(i,m[i],j,m[j])
                m.pop(j,None)
# Out:
# data analysis 6 data analytics 11
# data analysis 17 data analytics 11
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[75], line 2
#       1 for i in m:
# ----> 2     for j in m:
#       3         if i!=j:
#       4             if fuzz.ratio(i,j)>80:
#
# RuntimeError: dictionary changed size during iteration
